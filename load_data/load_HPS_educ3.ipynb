# %% [markdown]
# ## Purpose
#
# This Jupyter Notebook reads in Excel files that have been manually downloaded from the U.S. Census website: https://www.census.gov/programs-surveys/household-pulse-survey/data.html
#
# These files contain data from the Household Pulse Survey, "designed to quickly and efficiently deploy data collected on how people’s lives have been impacted by the COVID-19 pandemic."
#
# Specifically, this notebook reads in files from different weeks of data collection around technology access for education in families with children and extracts data from Washington State and the Seattle Metropolitan Area. The data from different weeks are appended to the same dataframe and exported as a CSV file.

# %% [markdown]
# ## Set up environment

# %%
# Import modules 
import pandas as pd # data manipulation

# %%
# Initialize list of file names 
# Raw files
raw_dir = '/home/jupyter/tech_access_usa/raw_data/HPS/educ/educ3/' # directory
raw_files = ["educ3_050520.xlsx", "educ3_051220.xlsx", "educ3_051920.xlsx", "educ3_052620.xlsx"]
# Save files
save_dir = '/home/jupyter/tech_access_usa/csv_data/' # directory
save_file = 'educ3.csv'

# %% [markdown]
# ## Import data

# %%
# Create list of characteristics 
select_characteristics = [None, "Total", 
                  None, "Age: 18-24", "Age: 25-39", "Age: 40-54", "Age: 55-64", "Age: 65 and above", 
                 None, "Gender: Male", "Gender: Female", 
                 None, "Hispanic origin and Race: Hispanic or Latino (may be of any race)", 
                  "Hispanic origin and Race: White alone, not Hispanic", 
                 "Hispanic origin and Race: Black alone, not Hispanic", 
                  "Hispanic origin and Race: Asian alone, not Hispanic", 
                  "Hispanic origin and Race: Two or more races + Other races, not Hispanic",
                 None, "Education: Less than high school", "Education: High school or GED", 
                 "Education: Some college/associate’s degree", "Education: Bachelor’s degree or higher",
                 None, "Marital status: Married", "Marital status: Widowed", "Marital status: Divorced/separated",
                 "Marital status: Never married", "Marital status: Did not report",
                 None, "Presence of children under 18 years old: Children in household", 
                 "Presence of children under 18 years old: No children",
                 None, "Computer provided by: Children’s school or school district", 
                 "Computer provided by: Someone in household or family or belongs to child", 
                 "Computer provided by: Some other source", "Computer provided by: Did not report", 
                 None, "Internet provided by: Children’s school or school district", 
                 "Internet provided by: Someone in household or family or belongs to child", 
                 "Internet provided by: Some other source", "Internet provided by: Did not report",
                 None, "Respondent or household member experienced loss of employment income: Yes", 
                 "Respondent or household member experienced loss of employment income: No", 
                 "Respondent or household member experienced loss of employment income: Did not report", 
                 None, "Respondent currently employed: Yes", 
                 "Respondent currently employed: No", 
                 "Respondent currently employed: Did not report", 
                 None, "Food sufficiency for households prior to March 13, 2020: Enough of the types of food wanted",
                 "Food sufficiency for households prior to March 13, 2020: Enough of the types of food wanted", 
                 "Food sufficiency for households prior to March 13, 2020: Sometimes not enough to eat", 
                 "Food sufficiency for households prior to March 13, 2020: Often not enough to eat", 
                 "Food sufficiency for households prior to March 13, 2020: Did not report", 
                 None, "Household income: Less than $25,000", "Household income: $25,000 - $34,999", 
                 "Household income: $35,000 - $49,999", "Household income: $50,000 - $74,999", 
                 "Household income: $75,000 - $99,999", "Household income: $100,000 - $149,999", 
                 "Household income: $150,000 - $199,999", "Household income: $200,000 and above", 
                 "Household income: Did not report", 
                 None]

# %%
# Initialize empty dataframe 
educ3_df = pd.DataFrame()

# %%
# Loop through files to extract data
for i in range(0, len(raw_files)):
    
    # Initilize list of locations from sheet names in Excel file 
    locations = pd.ExcelFile(raw_dir + raw_files[i]).sheet_names
    
    # Loop through locations to select sheet
    for j in range(0, len(locations)):
        #Read sheet from Excel file 
        file = pd.read_excel(raw_dir + raw_files[i], sheet_name = locations[j], skiprows = 4, na_values = '-')
        
        # Rename groups in "Select characteristics" column for better formatting
        file.iloc[:,0] = select_characteristics
        
        # Extract rows
        data = file.iloc[:,2:14]
        
        # Add columns to specify ...
        # location
        data.insert(0, "Location", locations[j])
        # date
        data.insert(1, "Date", [raw_files[i][6:12]]*file.shape[0], True) 
        # group 
        data.insert(2, "Group", file.iloc[:,0], True) 
        # total surveyed 
        data.insert(3, "Total", file.iloc[:,1], True)
        
        # Append to dataframe
        educ3_df = educ3_df.append(data)
        

# Show dataframe
educ3_df
# Out:
#                   Location    Date                                  Group  \
# 0                       US  050520                                   None
# 1                       US  050520                                  Total
# 2                       US  050520                                   None
# 3                       US  050520                             Age: 18-24
# 4                       US  050520                             Age: 25-39
# ..                     ...     ...                                    ...
# 61  Los.Angeles_Metro_Area  052620  Household income: $100,000 - $149,999
# 62  Los.Angeles_Metro_Area  052620  Household income: $150,000 - $199,999
# 63  Los.Angeles_Metro_Area  052620   Household income: $200,000 and above
# 64  Los.Angeles_Metro_Area  052620       Household income: Did not report
# 65  Los.Angeles_Metro_Area  052620                                   None
#
#          Total  Device always available for educational purposes  \
# 0          NaN                                               NaN
# 1   66561640.0                                        46713712.0
# 2          NaN                                               NaN
# 3    3091963.0                                         1951410.0
# 4   26509961.0                                        16846599.0
# ..         ...                                               ...
# 61    324430.0                                          275089.0
# 62    253893.0                                          241507.0
# 63    159867.0                                          143875.0
# 64     78359.0                                           41290.0
# 65         NaN                                               NaN
#
#     Device usually available for educational purposes  \
# 0                                                 NaN
# 1                                          11020451.0
# 2                                                 NaN
# 3                                            627894.0
# 4                                           4896617.0
# ..                                                ...
# 61                                            40710.0
# 62                                            12386.0
# 63                                            11118.0
# 64                                             1596.0
# 65                                                NaN
#
#     Device sometimes available for educational purposes  \
# 0                                                 NaN
# 1                                           4887743.0
# 2                                                 NaN
# 3                                            294423.0
# 4                                           2684805.0
# ..                                                ...
# 61                                             8631.0
# 62                                                NaN
# 63                                             4875.0
# 64                                                NaN
# 65                                                NaN
#
#     Device rarely available for educational purposes  \
# 0                                                NaN
# 1                                          1987773.0
# 2                                                NaN
# 3                                            91231.0
# 4                                          1300220.0
# ..                                               ...
# 61                                               NaN
# 62                                               NaN
# 63                                               NaN
# 64                                           18678.0
# 65                                               NaN
#
#     Device never available for educational purposes  Did not report  \
# 0                                               NaN             NaN
# 1                                         1096152.0        855810.0
# 2                                               NaN             NaN
# 3                                           61351.0         65655.0
# 4                                          489931.0        291788.0
# ..                                              ...             ...
# 61                                              NaN             NaN
# 62                                              NaN             NaN
# 63                                              NaN             NaN
# 64                                              NaN         16795.0
# 65                                              NaN             NaN
#
#     Internet always available for educational purposes  \
# 0                                                 NaN
# 1                                          48326505.0
# 2                                                 NaN
# 3                                           2010816.0
# 4                                          18412158.0
# ..                                                ...
# 61                                           277419.0
# 62                                           241025.0
# 63                                           140636.0
# 64                                            31313.0
# 65                                                NaN
#
#     Internet usually available for educational purposes  \
# 0                                                 NaN
# 1                                          11133943.0
# 2                                                 NaN
# 3                                            652620.0
# 4                                           4550103.0
# ..                                                ...
# 61                                            46254.0
# 62                                            12868.0
# 63                                            19231.0
# 64                                             2332.0
# 65                                                NaN
#
#     Internet sometimes available for educational purposes  \
# 0                                                 NaN
# 1                                           3308815.0
# 2                                                 NaN
# 3                                            126887.0
# 4                                           1808068.0
# ..                                                ...
# 61                                              757.0
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
#
#     Internet rarely available for educational purposes  \
# 0                                                 NaN
# 1                                           1411485.0
# 2                                                 NaN
# 3                                            118577.0
# 4                                            882815.0
# ..                                                ...
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
#
#     Internet never available for educational purposes  Did not report.1
# 0                                                 NaN               NaN
# 1                                           1034373.0         1346519.0
# 2                                                 NaN               NaN
# 3                                             39744.0          143318.0
# 4                                            360504.0          496313.0
# ..                                                ...               ...
# 61                                                NaN               NaN
# 62                                                NaN               NaN
# 63                                                NaN               NaN
# 64                                                NaN           44714.0
# 65                                                NaN               NaN
#
# [17688 rows x 16 columns]

# %% [markdown]
# ## Clean data
#
# Light data cleaning before export.

# %%
# Split Group column into two columns - one tracking higher level characteristic & one tracking group
educ3_df[["Characteristic", "Group"]] = educ3_df["Group"].str.split(": ", expand = True)

# %%
# Visual check
educ3_df
# Out:
#                   Location    Date                Group       Total  \
# 0                       US  050520                 None         NaN
# 1                       US  050520                 None  66561640.0
# 2                       US  050520                 None         NaN
# 3                       US  050520                18-24   3091963.0
# 4                       US  050520                25-39  26509961.0
# ..                     ...     ...                  ...         ...
# 61  Los.Angeles_Metro_Area  052620  $100,000 - $149,999    324430.0
# 62  Los.Angeles_Metro_Area  052620  $150,000 - $199,999    253893.0
# 63  Los.Angeles_Metro_Area  052620   $200,000 and above    159867.0
# 64  Los.Angeles_Metro_Area  052620       Did not report     78359.0
# 65  Los.Angeles_Metro_Area  052620                 None         NaN
#
#     Device always available for educational purposes  \
# 0                                                NaN
# 1                                         46713712.0
# 2                                                NaN
# 3                                          1951410.0
# 4                                         16846599.0
# ..                                               ...
# 61                                          275089.0
# 62                                          241507.0
# 63                                          143875.0
# 64                                           41290.0
# 65                                               NaN
#
#     Device usually available for educational purposes  \
# 0                                                 NaN
# 1                                          11020451.0
# 2                                                 NaN
# 3                                            627894.0
# 4                                           4896617.0
# ..                                                ...
# 61                                            40710.0
# 62                                            12386.0
# 63                                            11118.0
# 64                                             1596.0
# 65                                                NaN
#
#     Device sometimes available for educational purposes  \
# 0                                                 NaN
# 1                                           4887743.0
# 2                                                 NaN
# 3                                            294423.0
# 4                                           2684805.0
# ..                                                ...
# 61                                             8631.0
# 62                                                NaN
# 63                                             4875.0
# 64                                                NaN
# 65                                                NaN
#
#     Device rarely available for educational purposes  \
# 0                                                NaN
# 1                                          1987773.0
# 2                                                NaN
# 3                                            91231.0
# 4                                          1300220.0
# ..                                               ...
# 61                                               NaN
# 62                                               NaN
# 63                                               NaN
# 64                                           18678.0
# 65                                               NaN
#
#     Device never available for educational purposes  Did not report  \
# 0                                               NaN             NaN
# 1                                         1096152.0        855810.0
# 2                                               NaN             NaN
# 3                                           61351.0         65655.0
# 4                                          489931.0        291788.0
# ..                                              ...             ...
# 61                                              NaN             NaN
# 62                                              NaN             NaN
# 63                                              NaN             NaN
# 64                                              NaN         16795.0
# 65                                              NaN             NaN
#
#     Internet always available for educational purposes  \
# 0                                                 NaN
# 1                                          48326505.0
# 2                                                 NaN
# 3                                           2010816.0
# 4                                          18412158.0
# ..                                                ...
# 61                                           277419.0
# 62                                           241025.0
# 63                                           140636.0
# 64                                            31313.0
# 65                                                NaN
#
#     Internet usually available for educational purposes  \
# 0                                                 NaN
# 1                                          11133943.0
# 2                                                 NaN
# 3                                            652620.0
# 4                                           4550103.0
# ..                                                ...
# 61                                            46254.0
# 62                                            12868.0
# 63                                            19231.0
# 64                                             2332.0
# 65                                                NaN
#
#     Internet sometimes available for educational purposes  \
# 0                                                 NaN
# 1                                           3308815.0
# 2                                                 NaN
# 3                                            126887.0
# 4                                           1808068.0
# ..                                                ...
# 61                                              757.0
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
#
#     Internet rarely available for educational purposes  \
# 0                                                 NaN
# 1                                           1411485.0
# 2                                                 NaN
# 3                                            118577.0
# 4                                            882815.0
# ..                                                ...
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
#
#     Internet never available for educational purposes  Did not report.1  \
# 0                                                 NaN               NaN
# 1                                           1034373.0         1346519.0
# 2                                                 NaN               NaN
# 3                                             39744.0          143318.0
# 4                                            360504.0          496313.0
# ..                                                ...               ...
# 61                                                NaN               NaN
# 62                                                NaN               NaN
# 63                                                NaN               NaN
# 64                                                NaN           44714.0
# 65                                                NaN               NaN
#
#       Characteristic
# 0               None
# 1              Total
# 2               None
# 3                Age
# 4                Age
# ..               ...
# 61  Household income
# 62  Household income
# 63  Household income
# 64  Household income
# 65              None
#
# [17688 rows x 17 columns]

# %%
# Create count of original number of rows for later checking
orig_rows = educ3_df.shape[0]

# %%
# Show rows to drop that have NAs for all counting columns
educ3_df[educ3_df.apply(lambda x: x.count(), axis=1) < 5].iloc[:, 5:16]
# Out:
#     Device usually available for educational purposes  \
# 0                                                 NaN
# 2                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 17                                                NaN
# ..                                                ...
# 48                                                NaN
# 49                                                NaN
# 54                                                NaN
# 55                                                NaN
# 65                                                NaN
#
#     Device sometimes available for educational purposes  \
# 0                                                 NaN
# 2                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 17                                                NaN
# ..                                                ...
# 48                                                NaN
# 49                                                NaN
# 54                                                NaN
# 55                                                NaN
# 65                                                NaN
#
#     Device rarely available for educational purposes  \
# 0                                                NaN
# 2                                                NaN
# 8                                                NaN
# 11                                               NaN
# 17                                               NaN
# ..                                               ...
# 48                                               NaN
# 49                                               NaN
# 54                                               NaN
# 55                                               NaN
# 65                                               NaN
#
#     Device never available for educational purposes  Did not report  \
# 0                                               NaN             NaN
# 2                                               NaN             NaN
# 8                                               NaN             NaN
# 11                                              NaN             NaN
# 17                                              NaN             NaN
# ..                                              ...             ...
# 48                                              NaN             NaN
# 49                                              NaN             NaN
# 54                                              NaN             NaN
# 55                                              NaN             NaN
# 65                                              NaN             NaN
#
#     Internet always available for educational purposes  \
# 0                                                 NaN
# 2                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 17                                                NaN
# ..                                                ...
# 48                                                NaN
# 49                                                NaN
# 54                                                NaN
# 55                                                NaN
# 65                                                NaN
#
#     Internet usually available for educational purposes  \
# 0                                                 NaN
# 2                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 17                                                NaN
# ..                                                ...
# 48                                                NaN
# 49                                                NaN
# 54                                                NaN
# 55                                                NaN
# 65                                                NaN
#
#     Internet sometimes available for educational purposes  \
# 0                                                 NaN
# 2                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 17                                                NaN
# ..                                                ...
# 48                                                NaN
# 49                                                NaN
# 54                                                NaN
# 55                                                NaN
# 65                                                NaN
#
#     Internet rarely available for educational purposes  \
# 0                                                 NaN
# 2                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 17                                                NaN
# ..                                                ...
# 48                                                NaN
# 49                                                NaN
# 54                                                NaN
# 55                                                NaN
# 65                                                NaN
#
#     Internet never available for educational purposes  Did not report.1
# 0                                                 NaN               NaN
# 2                                                 NaN               NaN
# 8                                                 NaN               NaN
# 11                                                NaN               NaN
# 17                                                NaN               NaN
# ..                                                ...               ...
# 48                                                NaN               NaN
# 49                                                NaN               NaN
# 54                                                NaN               NaN
# 55                                                NaN               NaN
# 65                                                NaN               NaN
#
# [4526 rows x 11 columns]

# %%
# Show that all are NAs only 
educ3_df[educ3_df.apply(lambda x: x.count(), axis=1) < 5].iloc[:, 5:16].dropna()
# Out:
# Empty DataFrame
# Columns: [Device usually available for educational purposes, Device sometimes available for educational purposes, Device rarely available for educational purposes, Device never available for educational purposes, Did not report, Internet always available for educational purposes, Internet usually available for educational purposes, Internet sometimes available for educational purposes, Internet rarely available for educational purposes, Internet never available for educational purposes, Did not report.1]
# Index: []

# %%
# Count number of rows to drop -- where all the counting columns have missing values 
drop_rows = educ3_df[educ3_df.apply(lambda x: x.count(), axis=1) < 5].iloc[:, 5:16].shape[0]

# %%
# Drop rows where all columns containing counts have missing values 
educ3_df = educ3_df.loc[educ3_df.iloc[:, 5:16].isnull().sum(axis = 1) != 11,:]

# %%
# Check with counts 
educ3_df.shape[0] == orig_rows - drop_rows # check passed
# Out:
# True

# %% [markdown]
# ## Save data

# %%
# Save to CSV 
educ3_df.to_csv(save_dir + save_file, index=False)
