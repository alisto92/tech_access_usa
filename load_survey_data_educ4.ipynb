# %% [markdown]
# # Tech Access in the USA

# %% [markdown]
# ## Set up environment

# %%
# import modules 
import pandas as pd # data manipulation

# %% [markdown]
# ## Import data

# %%
# import WA data 
educ4 = pd.read_excel("educ4.xlsx", sheet_name = "WA", skiprows = 4, na_values = '-')
# visual check 
educ4.head()
# Out:
#     Unnamed: 0  Unnamed: 1  \
# 0          NaN         NaN
# 1        Total   1197656.0
# 2         Age          NaN
# 3      18 - 24     47816.0
# 4      25 - 39    385952.0
#
#    Provided by the children’s school or school district to use outside of school  \
# 0                                                NaN
# 1                                           503902.0
# 2                                                NaN
# 3                                            12476.0
# 4                                           171510.0
#
#    Provided by someone in the household or family, or it is the child’s  \
# 0                                                NaN
# 1                                           786927.0
# 2                                                NaN
# 3                                            39400.0
# 4                                           226831.0
#
#    Provided by another source  Did not report  \
# 0                         NaN             NaN
# ...

# %%
# Calculate percent respondents 
incomes = educ4.iloc[46:56,2:14].div(educ4.iloc[46:56,1], axis=0)
# Insert first column with group names 
incomes.insert(0, "Group", educ4.iloc[46:56,0], True) 
incomes
# Out:
#                                                 Group  \
# 46                                  Less than $25,000
# 47                                  $25,000 - $34,999
# 48                                  $35,000 - $49,999
# 49                                  $50,000 - $74,999
# 50                                  $75,000 - $99,999
# 51                                $100,000 - $149,999
# 52                                $150,000 - $199,999
# 53                                 $200,000 and above
# 54                                     Did not report
# 55  * Totals may not sum to 100% as the question a...
#
#     Provided by the children’s school or school district to use outside of school  \
# 46                                           0.630381
# 47                                           0.629679
# 48                                           0.472624
# 49                                           0.310047
# 50                                           0.559183
# ...

# %%
# Calculate percent respondents 
incomes = educ3.iloc[45:49,2:14].div(educ3.iloc[45:49,1], axis=0)
# Insert first column with group names 
incomes.insert(0, "Group", educ3.iloc[45:49,0], True) 
incomes
# Out:
#                              Group  \
# 45  Respondent currently employed
# 46                             Yes
# 47                              No
# 48                  Did not report
#
#     Device always available for educational purposes  \
# 45                                               NaN
# 46                                          0.823167
# 47                                          0.700479
# 48                                          1.000000
#
#     Device usually available for educational purposes  \
# 45                                                NaN
# 46                                           0.084833
# 47                                           0.172096
# 48                                                NaN
#
#     Device sometimes available for educational purposes  \
# 45                                                NaN
# 46                                           0.028211
# 47                                           0.032270
# ...

# %%
# Calculate percent respondents 
incomes = educ3.iloc[50:55,2:14].div(educ3.iloc[50:55,1], axis=0)
# Insert first column with group names 
incomes.insert(0, "Group", educ3.iloc[50:55,0], True) 
incomes
# Out:
#                                                Group  \
# 50                Enough of the types of food wanted
# 51      Enough food, but not always the types wanted
# 52                       Sometimes not enough to eat
# 53                           Often not enough to eat
# 54                                    Did not report
#
#     Device always available for educational purposes  \
# 50                                          0.811326
# 51                                          0.761217
# 52                                          0.568654
# 53                                          0.440558
# 54                                          1.000000
#
#     Device usually available for educational purposes  \
# 50                                           0.117474
# 51                                           0.100566
# 52                                           0.188064
# 53                                           0.026806
# ...

# %%
# The $25K-34,999 group not as expected -- were they provided assistance? 
# Calculate percent respondents 
incomes = educ3.iloc[56:65,2:14].div(educ3.iloc[56:65,1], axis=0)
# Insert first column with group names 
incomes.insert(0, "Group", educ3.iloc[56:65,0], True) 
incomes
# Out:
#                       Group  Device always available for educational purposes  \
# 56        Less than $25,000                                          0.571619
# 57        $25,000 - $34,999                                          0.825530
# 58        $35,000 - $49,999                                          0.589425
# 59        $50,000 - $74,999                                          0.785515
# 60        $75,000 - $99,999                                          0.827573
# 61      $100,000 - $149,999                                          0.857675
# 62      $150,000 - $199,999                                          0.883609
# 63       $200,000 and above                                          0.806397
# 64           Did not report                                          0.624428
#
#     Device usually available for educational purposes  \
# 56                                           0.197231
# 57                                           0.114088
# ...
