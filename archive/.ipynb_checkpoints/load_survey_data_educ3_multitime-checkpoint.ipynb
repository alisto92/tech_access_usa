# %% [markdown]
# # Tech Access in the USA

# %% [markdown]
# ## Purpose
#
# This Jupyter Notebook reads in Excel files that have been manually downloaded from the U.S. Census website: https://www.census.gov/programs-surveys/household-pulse-survey/data.html
#
# These files contain data from the Household Pulse Survey, "designed to quickly and efficiently deploy data collected on how people’s lives have been impacted by the COVID-19 pandemic."
#
# Specifically, this notebook reads in files from different weeks of data collection around technology access in families with children and extracts data from Washington State. We retain only rows that record technology access by different income groups. The data from different weeks are appended to the same dataframe and exported as a CSV file.

# %% [markdown]
# ## Set up environment

# %%
# import modules 
import pandas as pd # data manipulation
from datetime import datetime # handling dates

# %% [markdown]
# ## Import data

# %% [markdown]
# ### Income

# %%
# Initialize list of file names 
file_names = ["educ3_050520.xlsx", "educ3_051220.xlsx", "educ3_051920.xlsx", "educ3_052620.xlsx"]

locations = ["WA", "Seattle_Metro_Area"]


# Initialize empty dataframe 
income_df = pd.DataFrame()

# Loop through files to extract data
for i in range(0, len(file_names)):
    # Loop through locations to select sheet
    for j in range(0, len(locations)):
        # Read sheet from Excel file 
        file = pd.read_excel(file_names[i], sheet_name = locations[j], skiprows = 4, na_values = '-')
        # Extract income rows
        income = file.iloc[56:65,2:14]
        # Add column to specify location
        income.insert(0, "Location", locations[j])
        # Add column to specify date
        income.insert(1, "Date", [file_names[i][6:12]]*9, True) 
        # Add column to specify income group 
        income.insert(2, "Group", file.iloc[56:65,0], True) 
        # Add column to specify total surveyed 
        income.insert(3, "Total", file.iloc[56:65,1], True)
        # Append to dataframe
        income_df = income_df.append(income)

# Show dataframe
income_df
# Out:
#               Location    Date                    Group     Total  \
# 56                  WA  050520        Less than $25,000  126801.0
# 57                  WA  050520        $25,000 - $34,999  142422.0
# 58                  WA  050520        $35,000 - $49,999  137649.0
# 59                  WA  050520        $50,000 - $74,999  250272.0
# 60                  WA  050520        $75,000 - $99,999  125245.0
# ..                 ...     ...                      ...       ...
# 60  Seattle_Metro_Area  052620        $75,000 - $99,999   79481.0
# 61  Seattle_Metro_Area  052620      $100,000 - $149,999  126916.0
# 62  Seattle_Metro_Area  052620      $150,000 - $199,999   63847.0
# 63  Seattle_Metro_Area  052620       $200,000 and above  140252.0
# 64  Seattle_Metro_Area  052620           Did not report   40768.0
#
#     Device always available for educational purposes  \
# 56                                           82138.0
# 57                                           91223.0
# 58                                          104024.0
# 59                                          152880.0
# 60                                           93336.0
# ..                                               ...
# 60                                           69395.0
# 61                                          118355.0
# 62                                           54419.0
# 63                                          108925.0
# 64                                           31087.0
#
#     Device usually available for educational purposes  \
# 56                                            23821.0
# 57                                            34196.0
# 58                                            14927.0
# 59                                            62590.0
# 60                                            20611.0
# ..                                                ...
# 60                                            10086.0
# 61                                             7226.0
# 62                                             7437.0
# 63                                            29637.0
# 64                                             1388.0
#
#     Device sometimes available for educational purposes  \
# 56                                            15521.0
# 57                                             9156.0
# 58                                             2928.0
# 59                                            18203.0
# 60                                             4813.0
# ..                                                ...
# 60                                                NaN
# 61                                              457.0
# 62                                             1646.0
# 63                                             1008.0
# 64                                              204.0
#
#     Device rarely available for educational purposes  \
# 56                                            2661.0
# 57                                            7026.0
# 58                                            5103.0
# 59                                           16598.0
# 60                                            6485.0
# ..                                               ...
# 60                                               NaN
# 61                                             877.0
# 62                                               NaN
# 63                                             682.0
# 64                                               NaN
#
#     Device never available for educational purposes  Did not report  \
# 56                                           2661.0             NaN
# 57                                            820.0             NaN
# 58                                          10666.0             NaN
# 59                                              NaN             NaN
# 60                                              NaN             NaN
# ..                                              ...             ...
# 60                                              NaN             NaN
# 61                                              NaN             NaN
# 62                                              NaN           344.0
# 63                                              NaN             NaN
# 64                                              NaN          8088.0
#
#     Internet always available for educational purposes  \
# 56                                            72749.0
# 57                                            91048.0
# 58                                           107465.0
# 59                                           180698.0
# 60                                            79949.0
# ..                                                ...
# 60                                            72598.0
# 61                                           111580.0
# 62                                            57682.0
# 63                                           115003.0
# 64                                            25735.0
#
#     Internet usually available for educational purposes  \
# 56                                            43280.0
# 57                                            30024.0
# 58                                            19518.0
# 59                                            42946.0
# 60                                            39671.0
# ..                                                ...
# 60                                             5523.0
# 61                                            15336.0
# 62                                             5322.0
# 63                                            24561.0
# 64                                              204.0
#
#     Internet sometimes available for educational purposes  \
# 56                                             5450.0
# 57                                            10628.0
# 58                                                NaN
# 59                                            26627.0
# 60                                             5625.0
# ..                                                ...
# 60                                             1257.0
# 61                                                NaN
# 62                                              842.0
# 63                                              688.0
# 64                                                NaN
#
#     Internet rarely available for educational purposes  \
# 56                                             2661.0
# 57                                             9902.0
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     Internet never available for educational purposes  Did not report.1
# 56                                             2661.0               NaN
# 57                                              820.0               NaN
# 58                                            10666.0               NaN
# 59                                                NaN               NaN
# 60                                                NaN               NaN
# ..                                                ...               ...
# 60                                              102.0               NaN
# 61                                                NaN               NaN
# 62                                                NaN               NaN
# 63                                                NaN               NaN
# 64                                                NaN           14829.0
#
# [72 rows x 16 columns]

# %% [markdown]
# ### Food security

# %%
# Initialize empty dataframe 
food_df = pd.DataFrame()

# Loop through files to extract data
for i in range(0, len(file_names)):
    # Loop through locations to select sheet
    for j in range(0, len(locations)):
        # Read sheet from Excel file 
        file = pd.read_excel(file_names[i], sheet_name = locations[j], skiprows = 4, na_values = '-')
        # Extract income rows
        food = file.iloc[50:55,2:14]
        # Add column to specify location
        food.insert(0, "Location", locations[j])
        # Add column to specify date
        food.insert(1, "Date", [file_names[i][6:12]]*5, True)
        # Add column to specify income group 
        food.insert(2, "Group", file.iloc[50:55,0], True) 
        # Add column to specify total surveyed 
        food.insert(3, "Total", file.iloc[50:55,1], True)
        # Append to dataframe
        food_df = food_df.append(food)

# Show dataframe
food_df
# Out:
#               Location    Date  \
# 50                  WA  050520
# 51                  WA  050520
# 52                  WA  050520
# 53                  WA  050520
# 54                  WA  050520
# 50  Seattle_Metro_Area  050520
# 51  Seattle_Metro_Area  050520
# 52  Seattle_Metro_Area  050520
# 53  Seattle_Metro_Area  050520
# 54  Seattle_Metro_Area  050520
# 50                  WA  051220
# 51                  WA  051220
# 52                  WA  051220
# 53                  WA  051220
# 54                  WA  051220
# 50  Seattle_Metro_Area  051220
# 51  Seattle_Metro_Area  051220
# 52  Seattle_Metro_Area  051220
# 53  Seattle_Metro_Area  051220
# 54  Seattle_Metro_Area  051220
# 50                  WA  051920
# 51                  WA  051920
# 52                  WA  051920
# 53                  WA  051920
# 54                  WA  051920
# 50  Seattle_Metro_Area  051920
# 51  Seattle_Metro_Area  051920
# 52  Seattle_Metro_Area  051920
# 53  Seattle_Metro_Area  051920
# 54  Seattle_Metro_Area  051920
# 50                  WA  052620
# 51                  WA  052620
# 52                  WA  052620
# 53                  WA  052620
# 54                  WA  052620
# 50  Seattle_Metro_Area  052620
# 51  Seattle_Metro_Area  052620
# 52  Seattle_Metro_Area  052620
# 53  Seattle_Metro_Area  052620
# 54  Seattle_Metro_Area  052620
#
#                                                Group      Total  \
# 50                Enough of the types of food wanted  1044897.0
# 51      Enough food, but not always the types wanted   248673.0
# 52                       Sometimes not enough to eat    92317.0
# 53                           Often not enough to eat     2462.0
# 54                                    Did not report        NaN
# 50                Enough of the types of food wanted   590820.0
# 51      Enough food, but not always the types wanted    99431.0
# 52                       Sometimes not enough to eat    33153.0
# 53                           Often not enough to eat     2221.0
# 54                                    Did not report        NaN
# 50                Enough of the types of food wanted   897021.0
# 51      Enough food, but not always the types wanted   248131.0
# 52                       Sometimes not enough to eat   121997.0
# 53                           Often not enough to eat    29201.0
# 54                                    Did not report        NaN
# 50                Enough of the types of food wanted   530133.0
# 51      Enough food, but not always the types wanted   123473.0
# 52                       Sometimes not enough to eat     8500.0
# 53                           Often not enough to eat    24684.0
# 54                                    Did not report        NaN
# 50                Enough of the types of food wanted  1016666.0
# 51      Enough food, but not always the types wanted   238280.0
# 52                       Sometimes not enough to eat    75616.0
# 53                           Often not enough to eat    16463.0
# 54                                    Did not report      779.0
# 50                Enough of the types of food wanted   504290.0
# 51      Enough food, but not always the types wanted   106088.0
# 52                       Sometimes not enough to eat    28100.0
# 53                           Often not enough to eat    15972.0
# 54                                    Did not report        NaN
# 50                Enough of the types of food wanted   795743.0
# 51      Enough food, but not always the types wanted   312292.0
# 52                       Sometimes not enough to eat    73528.0
# 53                           Often not enough to eat    14325.0
# 54                                    Did not report     1768.0
# 50                Enough of the types of food wanted   412103.0
# 51      Enough food, but not always the types wanted   166679.0
# 52                       Sometimes not enough to eat    46300.0
# 53                           Often not enough to eat    13122.0
# 54                                    Did not report     1768.0
#
#     Device always available for educational purposes  \
# 50                                          816638.0
# 51                                          136434.0
# 52                                           44759.0
# 53                                            2462.0
# 54                                               NaN
# 50                                          482647.0
# 51                                           63980.0
# 52                                           14354.0
# 53                                            2221.0
# 54                                               NaN
# 50                                          693587.0
# 51                                          156898.0
# 52                                           61137.0
# 53                                               NaN
# 54                                               NaN
# 50                                          440906.0
# 51                                          104015.0
# 52                                            4139.0
# 53                                               NaN
# 54                                               NaN
# 50                                          728762.0
# 51                                          207495.0
# 52                                           19449.0
# 53                                               NaN
# 54                                             779.0
# 50                                          420112.0
# 51                                           92562.0
# 52                                           12790.0
# 53                                               NaN
# 54                                               NaN
# 50                                          645607.0
# 51                                          237722.0
# 52                                           41812.0
# 53                                            6311.0
# 54                                            1768.0
# 50                                          323925.0
# 51                                          147704.0
# 52                                           22004.0
# 53                                            5108.0
# 54                                            1768.0
#
#     Device usually available for educational purposes  \
# 50                                           168218.0
# 51                                            57694.0
# 52                                            19709.0
# 53                                                NaN
# 54                                                NaN
# 50                                            82515.0
# 51                                            22930.0
# 52                                             7547.0
# 53                                                NaN
# 54                                                NaN
# 50                                           129503.0
# 51                                            40204.0
# 52                                            19262.0
# 53                                             4518.0
# 54                                                NaN
# 50                                            57356.0
# 51                                            12908.0
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 50                                           180253.0
# 51                                            24416.0
# 52                                             6075.0
# 53                                              934.0
# 54                                                NaN
# 50                                            59019.0
# 51                                            11106.0
# 52                                             1562.0
# 53                                              444.0
# 54                                                NaN
# 50                                            93479.0
# 51                                            31406.0
# 52                                            13828.0
# 53                                              384.0
# 54                                                NaN
# 50                                            66940.0
# 51                                            13356.0
# 52                                            13828.0
# 53                                              384.0
# 54                                                NaN
#
#     Device sometimes available for educational purposes  \
# 50                                            29909.0
# 51                                            38066.0
# 52                                               57.0
# 53                                                NaN
# 54                                                NaN
# 50                                            17460.0
# 51                                            11699.0
# 52                                               57.0
# 53                                                NaN
# 54                                                NaN
# 50                                            14633.0
# 51                                            22775.0
# 52                                            37238.0
# 53                                                NaN
# 54                                                NaN
# 50                                             8586.0
# 51                                             2757.0
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 50                                            36659.0
# 51                                             5339.0
# 52                                            29256.0
# 53                                            12482.0
# 54                                                NaN
# 50                                            21829.0
# 51                                             1391.0
# 52                                             4650.0
# 53                                            12482.0
# 54                                                NaN
# 50                                            10628.0
# 51                                            15264.0
# 52                                             1982.0
# 53                                             7629.0
# 54                                                NaN
# 50                                             5708.0
# 51                                             4378.0
# 52                                             1982.0
# 53                                             7629.0
# 54                                                NaN
#
#     Device rarely available for educational purposes  \
# 50                                           10885.0
# 51                                            5865.0
# 52                                           25079.0
# 53                                               NaN
# 54                                               NaN
# 50                                            6782.0
# 51                                             822.0
# 52                                            8482.0
# 53                                               NaN
# 54                                               NaN
# 50                                            2037.0
# 51                                           27041.0
# 52                                               NaN
# 53                                           24684.0
# 54                                               NaN
# 50                                            2037.0
# 51                                            2580.0
# 52                                               NaN
# 53                                           24684.0
# 54                                               NaN
# 50                                            7120.0
# 51                                             740.0
# 52                                           20409.0
# 53                                            3046.0
# 54                                               NaN
# 50                                             414.0
# 51                                             740.0
# 52                                            8905.0
# 53                                            3046.0
# 54                                               NaN
# 50                                           20716.0
# 51                                           10418.0
# 52                                            7420.0
# 53                                               NaN
# 54                                               NaN
# 50                                            3752.0
# 51                                             682.0
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
#
#     Device never available for educational purposes  Did not report  \
# 50                                           9657.0          9590.0
# 51                                          10615.0             NaN
# 52                                           2713.0             NaN
# 53                                              NaN             NaN
# 54                                              NaN             NaN
# 50                                           1416.0             NaN
# 51                                              NaN             NaN
# 52                                           2713.0             NaN
# 53                                              NaN             NaN
# 54                                              NaN             NaN
# 50                                          30442.0         26819.0
# 51                                              NaN          1213.0
# 52                                              NaN          4361.0
# 53                                              NaN             NaN
# 54                                              NaN             NaN
# 50                                           2523.0         18724.0
# 51                                              NaN          1213.0
# 52                                              NaN          4361.0
# 53                                              NaN             NaN
# 54                                              NaN             NaN
# 50                                          63457.0           415.0
# 51                                            290.0             NaN
# 52                                            426.0             NaN
# 53                                              NaN             NaN
# 54                                              NaN             NaN
# 50                                           2500.0           415.0
# 51                                            290.0             NaN
# 52                                            193.0             NaN
# 53                                              NaN             NaN
# 54                                              NaN             NaN
# 50                                           3344.0         21969.0
# 51                                          16923.0           559.0
# 52                                           8485.0             NaN
# 53                                              NaN             NaN
# 54                                              NaN             NaN
# 50                                           3344.0          8433.0
# 51                                              NaN           559.0
# 52                                           8485.0             NaN
# 53                                              NaN             NaN
# 54                                              NaN             NaN
#
#     Internet always available for educational purposes  \
# 50                                           841228.0
# 51                                           143298.0
# 52                                            46648.0
# 53                                              241.0
# 54                                                NaN
# 50                                           489087.0
# 51                                            72007.0
# 52                                            16243.0
# 53                                                NaN
# 54                                                NaN
# 50                                           742125.0
# 51                                           181292.0
# 52                                            71096.0
# 53                                                NaN
# 54                                                NaN
# 50                                           453870.0
# 51                                            91146.0
# 52                                             4361.0
# 53                                                NaN
# 54                                                NaN
# 50                                           792827.0
# 51                                           208772.0
# 52                                            20575.0
# 53                                              444.0
# 54                                              779.0
# 50                                           452587.0
# 51                                            95532.0
# 52                                            13296.0
# 53                                              444.0
# 54                                                NaN
# 50                                           644525.0
# 51                                           192690.0
# 52                                            48799.0
# 53                                             7255.0
# 54                                             1768.0
# 50                                           326456.0
# 51                                           143563.0
# 52                                            26689.0
# 53                                             6052.0
# 54                                             1768.0
#
#     Internet usually available for educational purposes  \
# 50                                           148759.0
# 51                                            82212.0
# 52                                            17878.0
# 53                                             2221.0
# 54                                                NaN
# 50                                            89364.0
# 51                                            16085.0
# 52                                             5716.0
# 53                                             2221.0
# 54                                                NaN
# 50                                            82408.0
# 51                                            56872.0
# 52                                            13663.0
# 53                                             4518.0
# 54                                                NaN
# 50                                            39788.0
# 51                                            29145.0
# 52                                             4139.0
# 53                                                NaN
# 54                                                NaN
# 50                                           113337.0
# 51                                            17134.0
# 52                                             4285.0
# 53                                              491.0
# 54                                                NaN
# 50                                            40734.0
# 51                                             7181.0
# 52                                             1176.0
# 53                                                NaN
# 54                                                NaN
# 50                                           109285.0
# 51                                            70679.0
# 52                                             8822.0
# 53                                             6364.0
# 54                                                NaN
# 50                                            66935.0
# 51                                            15106.0
# 52                                             8822.0
# 53                                             6364.0
# 54                                                NaN
#
#     Internet sometimes available for educational purposes  \
# 50                                            31229.0
# 51                                             8851.0
# 52                                            16598.0
# 53                                                NaN
# 54                                                NaN
# 50                                            10953.0
# 51                                             7641.0
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 50                                             1202.0
# 51                                             8754.0
# 52                                            37238.0
# 53                                            24684.0
# 54                                                NaN
# 50                                             1202.0
# 51                                             1969.0
# 52                                                NaN
# 53                                            24684.0
# 54                                                NaN
# 50                                            39629.0
# 51                                            11653.0
# 52                                            30055.0
# 53                                            15528.0
# 54                                                NaN
# 50                                             4486.0
# 51                                             2720.0
# 52                                             4665.0
# 53                                            15528.0
# 54                                                NaN
# 50                                            15315.0
# 51                                            11292.0
# 52                                             1982.0
# 53                                              706.0
# 54                                                NaN
# 50                                             7646.0
# 51                                             1268.0
# 52                                             1982.0
# 53                                              706.0
# 54                                                NaN
#
#     Internet rarely available for educational purposes  \
# 50                                             2661.0
# 51                                             3698.0
# 52                                             6205.0
# 53                                                NaN
# 54                                                NaN
# 50                                                NaN
# 51                                             3698.0
# 52                                             6205.0
# 53                                                NaN
# 54                                                NaN
# 50                                             4079.0
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 50                                             1392.0
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 50                                              451.0
# 51                                              347.0
# 52                                            19516.0
# 53                                                NaN
# 54                                                NaN
# 50                                                NaN
# 51                                              281.0
# 52                                             8012.0
# 53                                                NaN
# 54                                                NaN
# 50                                             4892.0
# 51                                            13967.0
# 52                                             5118.0
# 53                                                NaN
# 54                                                NaN
# 50                                             2875.0
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#     Internet never available for educational purposes  Did not report.1
# 50                                             9657.0           11364.0
# 51                                            10615.0               NaN
# 52                                             4990.0               NaN
# 53                                                NaN               NaN
# 54                                                NaN               NaN
# 50                                             1416.0               NaN
# 51                                                NaN               NaN
# 52                                             4990.0               NaN
# 53                                                NaN               NaN
# 54                                                NaN               NaN
# 50                                            42709.0           24499.0
# 51                                                NaN            1213.0
# 52                                                NaN               NaN
# 53                                                NaN               NaN
# 54                                                NaN               NaN
# 50                                            14791.0           19090.0
# 51                                                NaN            1213.0
# 52                                                NaN               NaN
# 53                                                NaN               NaN
# 54                                                NaN               NaN
# 50                                            66038.0            4384.0
# 51                                               19.0             355.0
# 52                                             1185.0               NaN
# 53                                                NaN               NaN
# 54                                                NaN               NaN
# 50                                             2500.0            3983.0
# 51                                               19.0             355.0
# 52                                              951.0               NaN
# 53                                                NaN               NaN
# 54                                                NaN               NaN
# 50                                              102.0           21625.0
# 51                                            16923.0            6741.0
# 52                                                NaN            8807.0
# 53                                                NaN               NaN
# 54                                                NaN               NaN
# 50                                              102.0            8088.0
# 51                                                NaN            6741.0
# 52                                                NaN            8807.0
# 53                                                NaN               NaN
# 54                                                NaN               NaN

# %%
# Convert date columns to date object
income_df["Date"] = pd.to_datetime(income_df["Date"], format = '%m%d%y')
food_df["Date"] = pd.to_datetime(food_df["Date"], format = '%m%d%y')

# %%
# Save to CSV 
income_df.to_csv('educ3_income_multitime.csv', index=False)
food_df.to_csv('educ3_food_multitime.csv', index=False)
